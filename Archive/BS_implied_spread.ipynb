# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as web
from scipy import stats
import yfinance as yf
import matplotlib.pyplot as plt
# %matplotlib inline
from arch import arch_model

# %% [markdown]
# ## 1. Loading in datasets

# %% [markdown]
# #### (a) Dataset for Credit Default Swap spreads

# %%
cds_DF = pd.read_csv("datasets/cds.csv", parse_dates=['Date'])
cds_DF.head()
# Out:
#         Date Ticker                   Company     PX1    PX2     PX3     PX4  \
# 0 2015-01-01      A  Agilent Technologies Inc  14.850  25.05  39.055  73.715
# 1 2015-01-02      A  Agilent Technologies Inc  14.855  25.15  39.160  73.600
# 2 2015-01-05      A  Agilent Technologies Inc  13.455  24.96  39.310  70.200
# 3 2015-01-06      A  Agilent Technologies Inc  15.535  24.88  39.300  72.680
# 4 2015-01-07      A  Agilent Technologies Inc  15.215  25.50  40.270  73.880
#
#      PX5      PX6      PX7      PX8      PX9     PX10
# 0  86.30  111.305  125.905  144.300  158.600  168.195
# 1  86.40  111.510  126.100  144.375  158.775  168.375
# 2  88.26  111.970  125.060  143.165  157.385  166.825
# 3  91.10  116.610  130.890  150.365  165.655  175.885
# 4  92.50  117.780  131.940  151.145  166.215  176.295

# %% [markdown]
# #### (b) Dataset for equities of different companies

# %%
comp_stocks_DF = pd.read_csv("datasets/company_stock_data.csv", index_col='Date', parse_dates=True)
comp_stocks_DF.head()
# Out:
#                     A       AAPL       ABBV        ABT        ADM        ADP  \
# Date
# 2015-01-02  37.422062  24.347172  43.563179  37.108746  39.133045  67.362991
# 2015-01-05  36.720852  23.661274  42.743362  37.117004  37.778957  67.314476
# 2015-01-06  36.148819  23.663500  42.531784  36.695503  37.034214  66.756416
# 2015-01-07  36.628582  23.995317  44.250786  36.993034  37.590893  67.338745
# 2015-01-08  37.726505  24.917271  44.713577  37.753399  37.041733  68.883507
#
#                  AES        AFG  AGR        AIG  ...        WEC       WELL  \
# Date                                             ...
# 2015-01-02  9.684173  30.017288  NaN  44.253033  ...  38.417412  51.027782
# 2015-01-05  9.408492  29.623707  NaN  43.377602  ...  37.947937  51.657738
# 2015-01-06  9.196430  29.454308  NaN  42.762428  ...  38.049053  52.393814
# 2015-01-07  9.210567  29.648619  NaN  42.967476  ...  38.518543  52.877903
# 2015-01-08  9.351940  30.186687  NaN  42.778191  ...  38.944660  52.659077
#
#                   WFC         WHR         WM        WMB        WMT         WU  \
# Date
# 2015-01-02  41.032391  135.059799  42.477646  25.322723  23.493425  11.352100
# 2015-01-05  39.907192  132.274841  42.050804  24.320345  23.425055  11.244470
# 2015-01-06  39.074547  131.183243  42.083641  23.989943  23.605558  11.225472
# 2015-01-07  39.307091  134.269150  42.116470  23.861147  24.231873  11.117839
# 2015-01-08  40.177235  137.732925  42.600754  24.090736  24.743311  11.339439
#
#                    WY        XOM
# Date
# 2015-01-02  24.284630  60.042534
# 2015-01-05  24.284630  58.399651
# 2015-01-06  24.257740  58.089199
# 2015-01-07  24.331717  58.677792
# 2015-01-08  24.593996  59.654469
#
# [5 rows x 251 columns]

# %% [markdown]
# #### (c) Dataset for total asset value and total debt vale of companies

# %%
quarterly_DF = pd.read_csv("datasets/quarterly_company_data.csv", parse_dates=['datadate'])
quarterly_DF.head()
# Out:
#    gvkey   datadate  fyearq  fqtr indfmt consol popsrc datafmt  tic  \
# 0   1078 2014-12-31    2014   4.0   INDL      C      D     STD  ABT
# 1   1078 2015-03-31    2015   1.0   INDL      C      D     STD  ABT
# 2   1078 2015-06-30    2015   2.0   INDL      C      D     STD  ABT
# 3   1078 2015-09-30    2015   3.0   INDL      C      D     STD  ABT
# 4   1078 2015-12-31    2015   4.0   INDL      C      D     STD  ABT
#
#        cusip  ... costat dvpspq dvpsxq     mkvaltq      gind  gsector  \
# 0  002824100  ...      A   0.22   0.22  67891.7357  351010.0     35.0
# 1  002824100  ...      A   0.24   0.24  68974.1118  351010.0     35.0
# 2  002824100  ...      A   0.24   0.24  73150.8443  351010.0     35.0
# 3  002824100  ...      A   0.24   0.24  59996.9784  351010.0     35.0
# 4  002824100  ...      A   0.24   0.24  66137.3852  351010.0     35.0
#
#       gsubind  idbflag   naics  spcsrc
# 0  35101010.0        B  334510      B+
# 1  35101010.0        B  334510      B+
# 2  35101010.0        B  334510      B+
# 3  35101010.0        B  334510      B+
# 4  35101010.0        B  334510      B+
#
# [5 rows x 42 columns]

# %% [markdown]
# #### (d) risk free rate series

# %%
risk_free_rate_S = web.DataReader('TB3MS', 'fred', start=quarterly_DF['datadate'].min().strftime('%Y-%m-%d'), 
                                  end=quarterly_DF['datadate'].max().strftime('%Y-%m-%d'))

# %% [markdown]
# ## 2. Processing data

# %%
def create_correct_dataframe(comp_tick):
    """This function will given an ticker name of a company create a dataframe that is necessary for the
    implied CDS-spread model. The only prerequisite is that the above code is run and hence the right
    .csv files are loaded in"""
    #fetch quarterly comp data for atq and ltq
    temp_comp_quarter = quarterly_DF[quarterly_DF['tic'] == comp_tick][['datadate','atq','ltq','cshoq']]

    #create a date range of comp data in days
    quart_to_days = pd.date_range(start=temp_comp_quarter['datadate'].min(), end=temp_comp_quarter['datadate'].max())
    
    #set the previously made date range as index
    temp_comp_quarter = temp_comp_quarter.set_index('datadate').reindex(quart_to_days).reset_index(names='datadate')

    #interpolate for the NaN values in lineair fashion
    temp_comp_quarter = temp_comp_quarter.interpolate(method='linear', limit_direction='forward', axis=0).set_index('datadate')

    #load equity data of company ticker
    temp_comp_equity = comp_stocks_DF[comp_tick]
    
    #combine the datasets on same dates
    temp_comp_comb = pd.merge(temp_comp_quarter, temp_comp_equity, left_index=True, right_index=True)

    #add column for log returns for both equity and total asset values
    temp_comp_comb['log_returns_eq'] = np.log(temp_comp_comb[comp_tick] / temp_comp_comb[comp_tick].shift(1))
    temp_comp_comb['log_returns_as'] = np.log(temp_comp_comb['atq'] / temp_comp_comb['atq'].shift(1))*100 #This I dont know about

    #Add the actual CDS data
    temp_comp_CDS = cds_DF[cds_DF['Ticker'] == comp_tick][['Date', 'PX1', 'PX2', 'PX3', 'PX4', 'PX5', 'PX6', 'PX7', 'PX8', 'PX9', 'PX10']].set_index('Date')
    temp_comp_comb = pd.merge(temp_comp_comb, temp_comp_CDS, left_index=True, right_index=True)

    #Add the riskfree rate data
    temp_comp_comb['rfree'] = risk_free_rate_S.reindex(temp_comp_comb.index, method='bfill')

    return temp_comp_comb

#example usage
create_correct_dataframe('AAPL').head()
# Out:
#                       atq            ltq        cshoq       AAPL  \
# 2015-01-02  261878.444444  138424.266667  5824.993644  24.347172
# 2015-01-05  261855.111111  138211.666667  5822.855611  23.661274
# 2015-01-06  261847.333333  138140.800000  5822.142933  23.663500
# 2015-01-07  261839.555556  138069.933333  5821.430256  23.995317
# 2015-01-08  261831.777778  137999.066667  5820.717578  24.917271
#
#             log_returns_eq  log_returns_as    PX1     PX2     PX3     PX4  \
# 2015-01-02             NaN             NaN  8.300  11.100  12.900  16.800
# 2015-01-05       -0.028576        -0.00891  9.535  12.800  14.890  19.415
# 2015-01-06        0.000094        -0.00297  7.820  10.455  12.145  15.815
# 2015-01-07        0.013925        -0.00297  7.835  10.475  12.175  15.860
# 2015-01-08        0.037702        -0.00297  7.805  10.440  12.130  15.800
#
#                PX5     PX6     PX7     PX8     PX9   PX10  rfree
# 2015-01-02  23.600  31.805  36.705  42.800  47.605  51.60   0.02
# 2015-01-05  27.290  36.520  41.860  48.455  53.560  57.77   0.02
# 2015-01-06  22.225  30.110  34.905  40.905  45.670  49.67   0.02
# 2015-01-07  22.300  30.220  35.035  41.065  45.850  49.86   0.02
# 2015-01-08  22.215  30.115  34.910  40.920  45.695  49.70   0.02

# %%
#load all used ticker names in a list.
with open('datasets/tickers.txt', 'r') as ticks:
    tickers = ticks.read().split('\n')[:-1]

# %%
#create a dictionary with ticker names and corresponding dataframe created by create_correct_dataframe()
ticks_DF_dict = {}
for tick in tickers:
    try:
        temp_frame = create_correct_dataframe(tick)
        if len(temp_frame['atq'].dropna()) > 0.6 * len(temp_frame['atq']):
            ticks_DF_dict[tick] = create_correct_dataframe(tick)    
    except:
        print(tick, end=', ')
# Out:
# BMO, BNS, BRK, CM, MUV2.DE, RY, TD,

# %% [markdown]
# ## 3. Defining model and calculating implied spread

# %%
# from "pricing_models - Copy" import BS_implied_spread

# %%
def BS_implied_spread(asset_0, debt, T, r, sigma_asset):
    
    leverage = (debt * np.exp(-r * T)) / asset_0 
    d1 = (np.log(asset_0) - np.log(debt) + (r + sigma_asset**2 / 2) * T) / (sigma_asset * np.sqrt(T))
    d2 = d1 - sigma_asset * np.sqrt(T)

    implied_spread = -np.log((stats.norm.cdf(d2) + (stats.norm.cdf(-d1) / leverage)) / T)
    return implied_spread

# %%
# GARCH(1,1) volatility 

def flexible_garch_volatility(company_df, p=1, q=1, o=0):
    garch_model = arch_model((company_df['log_returns_as'].dropna())*100, vol="GARCH", p=p, q=q, mean='zero')
    garch_result = garch_model.fit(disp='off')
    company_df['sigma_daily'] = garch_result.conditional_volatility
        
    return company_df

# %%
plt.plot(ticks_DF_dict['AAPL']['log_returns_as'])

# %%
for tick, DF in ticks_DF_dict.items():
    garch_model = arch_model((DF['log_returns_as'].dropna())*100, vol="Garch", p=1, q=1, mean='Constant')    
    garch_result = garch_model.fit(disp='off')
    DF['sigma_garch'] = garch_result.conditional_volatility
# Out:
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\arch\univariate\base.py:768: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(

# %%
for tick, df in ticks_DF_dict.items():
    if 'sigma_garch' in df.columns:
        continue
    else:
        print(tick)

# %%
plt.figure(figsize=(12,10))
for tick, df in ticks_DF_dict.items():
    plt.plot(df['sigma_garch'])

# %%
# # GJR-GARCH(1,1,1) - incorporates 'leverage effect' 
# # which essentially is the noton that negative returns contribute more to volatility than positive returns

# gjr_garch_model = arch_model(df2["R"].loc['2000-01-01':'2020-01-01'], p=1, o=1, q=1)
# gjr_garch_result = gjr_garch_model.fit(last_obs = "2020-01-01", disp= "off")
# print("\nGJR-GARCH(1,1,1) Model Summary:")
# print(gjr_garch_result.summary())

# %%
#Calculate Imp-spread for every company
for tick, DF in ticks_DF_dict.items():
    daily_vol = np.std(DF['log_returns_as'].dropna())
    annualized_vol_naive = daily_vol * np.sqrt(252)

    #Trying with rolling window
    rolling_std = DF['log_returns_as'].rolling(window='365d').std()
    DF['annualized_vol_40d'] = rolling_std * np.sqrt(252)

    #Trying with weighted std on previous days
    ewm_std = DF['log_returns_as'].ewm(span=365, adjust=False).std()
    DF['annualized_vol_ewm'] = ewm_std * np.sqrt(252)

    DF['imp_spread'] = BS_implied_spread(DF['atq'], DF['ltq'], 1, DF['rfree'],DF['sigma_garch']*np.sqrt(365))
# Out:
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.plot(ticks_DF_dict['AAPL']['log_returns_as'].dropna())
# plt.plot(ticks_DF_dict['APD']['rfree'])

# %%
#Calculate simple pearson correlation for now between implied spread and actual CDS data
cor_list = []
for tick, DF in ticks_DF_dict.items():
    cor = DF['imp_spread'].corr(DF['PX1'])
    cor_list.append(cor)
    print(f"{tick}: {cor:.5g}")
# Out:
# A: nan
# AAPL: nan
# ABBV: nan
# ABT: nan
# ADM: nan
# ADP: nan
# AES: nan
# AFG: nan
# AGR: nan
# AIG: nan
# ALL: nan
# ALLY: nan
# AMAT: nan
# AMGN: nan
# AMP: nan
# AMT: nan
# AMZN: nan
# AN: nan
# APD: nan
# ARW: nan
# ASML: nan
# AVB: nan
# AVT: nan
# AVY: nan
# AXP: nan
# AZN: nan
# AZO: nan
# BA: nan
# BABA: nan
# BAC: nan
# BAX: nan
# BBY: nan
# BDX: nan
# BIDU: nan
# BK: nan
# BMY: nan
# BSX: nan
# BWA: nan
# C: nan
# CAG: nan
# CAH: nan
# CAR: nan
# CAT: nan
# CB: nan
# CCI: nan
# CI: nan
# CL: nan
# CLX: nan
# CMCSA: nan
# CMI: nan
# CNA: nan
# CNP: nan
# COF: nan
# COP: nan
# COST: nan
# CPB: nan
# CPT: nan
# CSCO: nan
# CSTM: nan
# CSX: nan
# CVS: nan
# CVX: nan
# D: nan
# DAL: nan
# DB: nan
# DE: nan
# DGX: nan
# DHI: nan
# DHR: nan
# DOV: nan
# DRI: nan
# DTE: nan
# DVN: nan
# DXC: nan
# ED: nan
# EMN: nan
# EMR: nan
# EOG: nan
# EQIX: nan
# EQNR: nan
# ET: nan
# ETN: nan
# ETR: nan
# EXPE: nan
# F: nan
# FDX: nan
# FIS: 0.39609
# FLEX: nan
# FRT: nan
# FTI: nan
# GD: nan
# GE: nan
# GILD: nan
# GIS: nan
# GLW: nan
# GM: nan
# GS: nan
# GSK: nan
# GT: nan
# HAL: nan
# HAS: nan
# HD: nan
# HES: nan
# HIG: nan
# HON: nan
# HPQ: nan
# HRB: nan
# HSBC: nan
# HSY: nan
# HUM: nan
# HUN: nan
# IBM: nan
# IGT: nan
# INTC: nan
# INTU: nan
# IP: nan
# IPG: nan
# ITW: nan
# JCI: nan
# JEF: nan
# JNJ: nan
# JNPR: nan
# JPM: nan
# JWN: nan
# K: nan
# KIM: nan
# KMB: nan
# KMI: nan
# KO: nan
# KR: nan
# KSS: nan
# L: nan
# LEN: nan
# LH: nan
# LLY: nan
# LMT: nan
# LNC: nan
# LOW: nan
# LUV: nan
# MAR: nan
# MAS: nan
# MCD: nan
# MCK: nan
# MDLZ: nan
# MET: nan
# MHK: nan
# MLM: nan
# MMC: nan
# MMM: nan
# MO: nan
# MOS: nan
# MPC: nan
# MPLX: nan
# MRK: nan
# MRO: nan
# MS: nan
# MSFT: nan
# MSI: nan
# NEE: nan
# NEM: nan
# NFLX: nan
# NI: nan
# NKE: nan
# NOC: nan
# NRG: nan
# NSANY: nan
# NSC: nan
# NUE: nan
# NVR: nan
# NWG: nan
# OC: nan
# OI: nan
# OKE: nan
# OMC: nan
# ORCL: nan
# PAA: nan
# PCG: nan
# PEP: nan
# PFE: nan
# PG: nan
# PGR: nan
# PHM: nan
# PKG: nan
# PM: nan
# PNC: nan
# PPG: nan
# PRU: nan
# R: nan
# REG: nan
# RL: nan
# RSG: nan
# RTX: nan
# SCHW: nan
# SCOR: nan
# SEB: nan
# SEE: nan
# SHW: nan
# SKM: nan
# SLB: nan
# SLG: nan
# SO: nan
# SPGI: nan
# SRE: nan
# STZ: nan
# SWK: nan
# SYY: nan
# T: nan
# TAP: nan
# TEVA: nan
# TGT: nan
# TJX: nan
# TRV: nan
# TSN: nan
# TT: nan
# TXN: nan
# TXT: nan
# UBS: nan
# UDR: nan
# UHS: nan
# UNH: nan
# UNM: nan
# UNP: nan
# UPS: nan
# URI: nan
# USB: nan
# VFC: nan
# VLO: nan
# VMC: nan
# VOD: nan
# VZ: nan
# WBA: nan
# WEC: nan
# WELL: nan
# WFC: nan
# WHR: nan
# WM: nan
# WMB: nan
# WMT: nan
# WU: nan
# WY: nan
# XOM: nan
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\david\anaconda3\envs\SDA\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]

# %%
#Mean of the correlation list (not that high yet)
print(pd.Series(cor_list).dropna().mean())
print(pd.Series(cor_list).dropna().std())
# Out:
# 0.3960879364286143
# nan

# %% [markdown]
# ## Appendix: Just some testing

# %%
apple_temp = ticks_DF_dict['AAPL']

daily_vol = np.std(apple_temp['log_returns_as'].dropna())
annualized_vol_naive = daily_vol * np.sqrt(252)
print(annualized_vol_naive)

rolling_std = apple_temp['log_returns_as'].rolling(window='40d', closed='left').std()
apple_temp['annualized_vol_40d'] = rolling_std * np.sqrt(252)

ewm_std = apple_temp['log_returns_as'].ewm(span=365, adjust=False).std()
apple_temp['annualized_vol_ewm'] = ewm_std * np.sqrt(252)

temp_imp_spread_apple = BS_implied_spread(apple_temp['atq']/apple_temp['cshoq'], apple_temp['ltq']/apple_temp['cshoq'], 
                                          1, apple_temp['rfree'], apple_temp['annualized_vol_ewm'])
# Out:
# 1.5118565769701386

# %%
plt.plot(ticks_DF_dict['AAPL']['imp_spread'])
# plt.plot(apple_temp.index, apple_temp['PX1'])
